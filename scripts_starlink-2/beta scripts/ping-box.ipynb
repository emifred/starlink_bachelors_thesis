# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from datetime import datetime


import seaborn as sns

# %%
file1 = 'pingpacketloss.csv'

df1 = pd.read_csv(file1)
df1 = pd.read_csv(file1)
df1['Timestamp'] = pd.to_datetime(df1['Timestamp'])
df1['Timestamp'] = df1['Timestamp'].dt.date
df1 = df1.set_index('Timestamp')

#df1['Timestamp'] = pd.to_datetime(df1['Timestamp'])

sns.boxplot(x=df1.index,y='Packetloss', data=df1)
plt.xlabel('Date')
plt.ylabel('Packetloss')
plt.title('Boxplot of Packetloss per Date')
plt.xticks(rotation=90)
plt.show()
df1
# Out:
#             Packetloss
# Timestamp
# 2024-04-26         0.0
# 2024-04-26         0.0
# 2024-04-26         0.0
# 2024-04-26         0.0
# 2024-04-26         0.0
# ...                ...
# 2024-05-03        52.5
# 2024-05-03         5.0
# 2024-05-03        12.5
# 2024-05-03         2.5
# 2024-05-03        67.5
#
# [7921 rows x 1 columns]
